# %% [markdown]
# <span style="font-size:30pt; font-weight:bold;">Analysis of Satellite orbiting Earth </span>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("UCS-Satellite-Database-1-1-2023.csv",encoding='latin-1')
df2 = pd.read_csv("UCS-Satellite-Database-Officialname-1-1-2023.csv",encoding='latin-1')

# %%
df1.head(5)
# Out:
#                   Name of Satellite, Alternate Names  \
# 0  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                                           Aalto-1
# 2                                              AAt-4
# 3                           ABS-2 (Koreasat-8, ST-3)
# 4                                             ABS-2A
#
#   Current Official Name of Satellite Country/Org of UN Registry  \
# 0                         1HOPSAT-TD                         NR
# 1                            Aalto-1                    Finland
# 2                              AAt-4                    Denmark
# 3                              ABS-2                         NR
# 4                             ABS-2A                         NR
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 0                       USA                   Hera Systems  Commercial
# 1                   Finland               Aalto University       Civil
# ...

# %%
df2.head(5)
# Out:
#   Current Official Name of Satellite Country/Org of UN Registry  \
# 0                         1HOPSAT-TD                         NR
# 1                            Aalto-1                    Finland
# 2                              AAt-4                    Denmark
# 3                              ABS-2                         NR
# 4                             ABS-2A                         NR
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 0                       USA                   Hera Systems  Commercial
# 1                   Finland               Aalto University       Civil
# 2                   Denmark          University of Aalborg       Civil
# 3             Multinational  Asia Broadcast Satellite Ltd.  Commercial
# 4             Multinational  Asia Broadcast Satellite Ltd.  Commercial
#
#                   Purpose                       Detailed Purpose  \
# 0       Earth Observation                       Infrared Imaging
# ...

# %% [markdown]
# <span style="font-size:20; font-weight:bold;">Data Cleaning </span>
# ###### Removing null value

# %%
df1.columns
# Out:
# Index(['Name of Satellite, Alternate Names',
#        'Current Official Name of Satellite', 'Country/Org of UN Registry',
#        'Country of Operator/Owner', 'Operator/Owner', 'Users', 'Purpose',
#        'Detailed Purpose', 'Class of Orbit', 'Type of Orbit',
#        'Longitude of GEO (degrees)', 'Perigee (km)', 'Apogee (km)',
#        'Eccentricity', 'Inclination (degrees)', 'Period (minutes)',
#        'Launch Mass (kg.)', ' Dry Mass (kg.) ', 'Power (watts)',
#        'Date of Launch', 'Expected Lifetime (yrs.)', 'Contractor',
#        'Country of Contractor', 'Launch Site', 'Launch Vehicle',
#        'COSPAR Number', 'NORAD Number', 'Comments', 'Unnamed: 28',
#        'Source Used for Orbital Data', 'Source', 'Source.1', 'Source.2',
#        'Source.3', 'Source.4', 'Source.5', 'Source.6', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
# ...

# %%
df1_cleaned = df1.dropna()
df1_cleaned.columns
# Out:
# Index(['Name of Satellite, Alternate Names',
#        'Current Official Name of Satellite', 'Country/Org of UN Registry',
#        'Country of Operator/Owner', 'Operator/Owner', 'Users', 'Purpose',
#        'Detailed Purpose', 'Class of Orbit', 'Type of Orbit',
#        'Longitude of GEO (degrees)', 'Perigee (km)', 'Apogee (km)',
#        'Eccentricity', 'Inclination (degrees)', 'Period (minutes)',
#        'Launch Mass (kg.)', ' Dry Mass (kg.) ', 'Power (watts)',
#        'Date of Launch', 'Expected Lifetime (yrs.)', 'Contractor',
#        'Country of Contractor', 'Launch Site', 'Launch Vehicle',
#        'COSPAR Number', 'NORAD Number', 'Comments', 'Unnamed: 28',
#        'Source Used for Orbital Data', 'Source', 'Source.1', 'Source.2',
#        'Source.3', 'Source.4', 'Source.5', 'Source.6', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
# ...

# %%
# Filtering rows with NaN values in df1
rows_with_nan = df1[df1.isnull().any(axis=1)]

# Displaying the rows with NaN values
rows_with_nan

# Filtering rows with no NaN values in df1
rows_without_nan = df1.dropna()

# Displaying the rows with no NaN values
rows_without_nan
# Out:
# Empty DataFrame
# ...

# %%
#df1 = df1.dropna()
#df2 = df2.dropna()

# %% [markdown]
# <span style="font-size:20pt; font-weight:bold;">Visualisation </span>

# %%
plt.figure(figsize=(10, 6))
df1['Purpose'].value_counts().plot(kind='bar')
plt.title('Distribution of Satellites by Purpose')
plt.xlabel('Purpose')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 5))
df1['Class of Orbit'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.legend(labels=orbit_counts.index, loc='center left', bbox_to_anchor=(1, 0.5), title='Orbit Class')

plt.title('Distribution of Satellites by Orbit Class')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'Class of Orbit' is a column in df1
orbit_counts = df1['Class of Orbit'].value_counts()

# Plotting the pie chart without labels
plt.figure(figsize=(8, 5))
ax = df1['Class of Orbit'].value_counts().plot(kind='pie', autopct='', labels=None)

# Adding data points on the side of the pie chart
total = sum(orbit_counts)
for i, (orbit, count) in enumerate(zip(orbit_counts.index, orbit_counts)):
    percentage = (count / total) * 100
    plt.text(1.1, i / len(orbit_counts), f'{orbit}: {count} ({percentage:.1f}%)', va='center')

plt.title('Distribution of Satellites by Orbit Class')
plt.show()

# %% [markdown]
# This pie chart displays the distribution of satellites based on their class of orbit. It illustrates the proportion of satellites in different orbital classes, such as Low Earth Orbit (LEO), Geostationary Orbit (GEO), or others.

# %%
plt.figure(figsize = (12,6))
df1['Country of Operator/Owner'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Countries with Most Satellite Operators/Owners')
plt.xlabel('Country')
plt.ylabel('Number of Satellites')
plt.show()

# %% [markdown]
# This bar chart displays the top 10 countries based on the number of satellite operators or owners. It gives an overview of which countries have a more significant presence in terms of operating or owning operational satellites.

# %%
# Convert 'Launch Mass (kg.)' column to numeric if it's not already in numeric format
df1['Launch Mass (kg.)'] = pd.to_numeric(df1['Launch Mass (kg.)'], errors='coerce')

# Drop rows with missing launch mass data
df1.dropna(subset=['Launch Mass (kg.)'], inplace=True)

# Create boxplot: Launch Mass Distribution by Purpose
plt.figure(figsize=(10, 6))
sns.boxplot(x='Purpose', y='Launch Mass (kg.)', data=df1)
plt.title('Launch Mass Distribution by Purpose')
plt.xlabel('Purpose')
plt.ylabel('Launch Mass (kg.)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# This boxplot visualizes the distribution of launch masses across different satellite purposes. It allows for comparison of the spread and central tendency of launch masses for various purposes, highlighting potential differences or outliers in satellite mass based on their intended use (e.g., communication, Earth observation, etc.).

# %%
# Convert 'Date of Launch' column to datetime format, inferring the date format
df1['Date of Launch'] = pd.to_datetime(df1['Date of Launch'], errors='coerce', infer_datetime_format=True)

# Extract year from launch date
df1['Launch Year'] = df1['Date of Launch'].dt.year

plt.figure(figsize=(12, 6))
sns.lineplot(x='Launch Year', y='Launch Mass (kg.)', data=df1)
plt.title('Launch Mass Distribution Over Time')
plt.xlabel('Launch Year')
plt.ylabel('Launch Mass (kg.)')
plt.show()

# %% [markdown]
# This line plot shows the trend of launch mass distribution over time, helping to understand if there are any patterns or changes in satellite launch masses across different years.

# %%
plt.figure(figsize=(10, 6))
top_vehicles = df1['Launch Vehicle'].value_counts().head(5)
top_vehicles.plot(kind='bar')
plt.title('Top 5 Launch Vehicles Used')
plt.xlabel('Launch Vehicle')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This bar chart displays the top 5 launch vehicles frequently used for satellite launches, giving insights into the preferred vehicles for deploying satellites into orbit.
